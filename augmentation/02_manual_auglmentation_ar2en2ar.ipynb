# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"intent":"pay_bill","text":"ادفع فاتورة الكهرباء الخاصة بك"},
    {"intent":"pay_bill","text":"ادفع فاتورة المياه الخاصة بك"},
    {"intent":"pay_bill","text":"ادفع فاتورة الإنترنت الخاصة بك"},
    {"intent":"pay_bill","text":"ادفع فاتورة هاتفك"},
    {"intent":"pay_bill","text":"ادفع فاتورة الغاز الخاصة بك"},
    {"intent":"pay_bill","text":"ادفع الرسوم الجامعية"},
    {"intent":"pay_bill","text":"ادفع فاتورة المياه المتأخرة"},
    {"intent":"pay_bill","text":"ادفع فاتورة الكهرباء لهذا الشهر."},
    {"intent":"pay_bill","text":"ادفع فاتورة هاتفك الأرضي"},
    {"intent":"pay_bill","text":"ادفع فاتورة الإنترنت لشهر أغسطس"},
    {"intent":"pay_bill","text":"ادفع الرسوم الدراسية"},
    {"intent":"pay_bill","text":"ادفع ضريبة العقار"},
    {"intent":"pay_bill","text":"ادفع فاتورة الإنترنت عبر الألياف الضوئية"},
    {"intent":"pay_bill","text":"ادفع فاتورة الكهرباء فوراً"},
    {"intent":"pay_bill","text":"ادفع فاتورة المياه اليوم"},
    {"intent":"pay_bill","text":"ادفع رسوم الاشتراك في باقة الهاتف المحمول"},
    {"intent":"pay_bill","text":"ادفع فاتورة التلفزيون الخاصة بك"},
    {"intent":"pay_bill","text":"ادفع غرامة المرور"},
    {"intent":"pay_bill","text":"ادفع رسوم الجامعة لهذا الفصل الدراسي."},
    {"intent":"pay_bill","text":"ادفع فاتورة الغاز الآن"},
    {"intent":"pay_bill","text":"ادفع فاتورة المياه للمنزل"},
    {"intent":"pay_bill","text":"ادفع فاتورة الكهرباء باسم المنزل."},
    {"intent":"pay_bill","text":"ادفع فاتورة هاتفك الشهرية"},
    {"intent":"pay_bill","text":"دفع رسوم الخدمة"},
    {"intent":"pay_bill","text":"ادفع فاتورة شركة الهاتف الخاصة بك"},
    {"intent":"pay_bill","text":"ادفع فاتورة الإنترنت الخاصة بك للشهر الماضي."},
    {"intent":"pay_bill","text":"ادفع فاتورة المياه لهذا الشهر."},
    {"intent":"pay_bill","text":"ادفع فاتورة الكهرباء المتأخرة."},
    {"intent":"pay_bill","text":"ادفع فاتورة هاتفك"},
    {"intent":"pay_bill","text":"ادفع الفاتورة المستحقة."},
    {"intent":"p2p_transfer","text":"حوّل 5 دنانير إلى أحمد"},
    {"intent":"p2p_transfer","text":"حوّل 10 دنانير إلى ليلى"},
    {"intent":"p2p_transfer","text":"حوّل 15 دينارًا إلى محمد"},
    {"intent":"p2p_transfer","text":"حوّل 20 دينارًا إلى سارة"},
    {"intent":"p2p_transfer","text":"حوّل 25 دينار إلى خالد"},
    {"intent":"p2p_transfer","text":"حوّل 30 دينار إلى رنا"},
    {"intent":"p2p_transfer","text":"حوّل 35 دينار إلى عمر"},
    {"intent":"p2p_transfer","text":"حوّل 40 دينار إلى مريم"},
    {"intent":"p2p_transfer","text":"حوّل 45 دينار إلى يوسف"},
    {"intent":"p2p_transfer","text":"حوّل 50 دينارًا إلى هبة"},
    {"intent":"p2p_transfer","text":"حوّل 60 دينارًا إلى نور"},
    {"intent":"p2p_transfer","text":"حوّل 70 دينارًا إلى علي"},
    {"intent":"p2p_transfer","text":"حوّل 80 دينار إلى تالا"},
    {"intent":"p2p_transfer","text":"حوّل 90 دينار إلى سلمى"},
    {"intent":"p2p_transfer","text":"حوّل 100 دينار إلى زيد"},
    {"intent":"p2p_transfer","text":"حوّل دينارين إلى أحمد"},
    {"intent":"p2p_transfer","text":"حوّل ثلاث دنانير إلى ليلى"},
    {"intent":"p2p_transfer","text":"حوّل أربعة دنانير إلى محمد"},
    {"intent":"p2p_transfer","text":"حوّل 12 دينار إلى سارة اليوم"},
    {"intent":"p2p_transfer","text":"حوّل 18 دينار إلى خالد الآن"},
    {"intent":"p2p_transfer","text":"حوّل 22 دينار إلى رنا فورًا"},
    {"intent":"p2p_transfer","text":"حوّل 37 دينار إلى عمر"},
    {"intent":"p2p_transfer","text":"حوّل 55 دينار إلى مريم"},
    {"intent":"p2p_transfer","text":"حوّل 75 دينار إلى يوسف"},
    {"intent":"p2p_transfer","text":"حوّل 95 دينار إلى هبة"},
    {"intent":"p2p_transfer","text":"حوّل مبلغ 10 دنانير إلى حمزة"},
    {"intent":"p2p_transfer","text":"حوّل مبلغ 15 دينار إلى ريم"},
    {"intent":"p2p_transfer","text":"حوّل مبلغ 20 دينار إلى مراد"},
    {"intent":"p2p_transfer","text":"حوّل 8 دنانير إلى سمير"},
    {"intent":"p2p_transfer","text":"حوّل 13 دينار إلى فرح"},
    {"intent":"check_balance","text":"كم رصيدي المتبقي؟"},
    {"intent":"check_balance","text":"عرض الرصيد"},
    {"intent":"check_balance","text":"ما هو الرصيد الحالي؟"},
    {"intent":"check_balance","text":"ما تبقى في المحفظة؟"},
    {"intent":"check_balance","text":"أعطني رصيدي"},
    {"intent":"check_balance","text":"عرض الرصيد المتاح"},
    {"intent":"check_balance","text":"كم ستبقى معي؟"},
    {"intent":"check_balance","text":"ما هو رصيدي الآن؟"},
    {"intent":"check_balance","text":"عرض رصيد المحفظة"},
    {"intent":"check_balance","text":"كم من المال يوجد؟"},
    {"intent":"check_balance","text":"عرض الرصيد بدون تفاصيل"},
    {"intent":"check_balance","text":"أرني رصيدي الحالي"},
    {"intent":"check_balance","text":"هل يوجد ما يكفي من المال للدفع؟"},
    {"intent":"check_balance","text":"هل لدي رصيد كافٍ؟"},
    {"intent":"check_balance","text":"عرض آخر رصيد"},
    {"intent":"check_balance","text":"ما هو رصيد البطاقة؟"},
    {"intent":"check_balance","text":"ما هو الرصيد بعد آخر عملية شراء؟"},
    {"intent":"check_balance","text":"أعطني المبلغ الإجمالي."},
    {"intent":"check_balance","text":"عرض الرصيد الفوري"},
    {"intent":"check_balance","text":"أريد أن أعرف التوازن الآن."},
    {"intent":"check_balance","text":"إظهار الرصيد الإجمالي"},
    {"intent":"check_balance","text":"ما هو رصيد حسابي؟"},
    {"intent":"check_balance","text":"أريد أن أعرف رصيد محفظتي."},
    {"intent":"check_balance","text":"أظهر الرصيد الآن"},
    {"intent":"check_balance","text":"ما هو الرصيد المتبقي؟"},
    {"intent":"check_balance","text":"كم يبلغ رصيد البطاقة مسبقة الدفع؟"},
    {"intent":"check_balance","text":"ما هو الرصيد الإجمالي؟"},
    {"intent":"check_balance","text":"اطلع على رصيدك اليوم"},
    {"intent":"check_balance","text":"أعطني الرصيد الحالي بالضبط."},
    {"intent":"check_balance","text":"عرض رصيد الحساب الرئيسي"},
    {"intent":"unknown","text":"كيف حال الطقس اليوم؟"},
    {"intent":"unknown","text":"ذكرني غداً في الساعة الثامنة."},
    {"intent":"unknown","text":"أين هو أقرب مطعم؟"},
    {"intent":"unknown","text":"افتح الكاميرا"},
    {"intent":"unknown","text":"أرسل رسالة إلى صديقي"},
    {"intent":"unknown","text":"ما هي آخر الأخبار؟"},
    {"intent":"unknown","text":"شغل الموسيقى"},
    {"intent":"unknown","text":"لقد خرج من التطبيق"},
    {"intent":"unknown","text":"ابحث عن عنوان الجامعة"},
    {"intent":"unknown","text":"افتح الإعدادات"},
    {"intent":"unknown","text":"أشعر بالجوع"},
    {"intent":"unknown","text":"لقطات الشاشة"},
    {"intent":"unknown","text":"غيّر اللغة"},
    {"intent":"unknown","text":"ارفع مستوى الصوت"},
    {"intent":"unknown","text":"خفّضوا الأضواء"},
    {"intent":"unknown","text":"متى ستقام المباراة؟"},
    {"intent":"unknown","text":"ابحث على جوجل"},
    {"intent":"unknown","text":"افتح يوتيوب"},
    {"intent":"unknown","text":"احسب 5 زائد 7"},
    {"intent":"unknown","text":"أحتاج إلى خريطة للمكان."},
    {"intent":"unknown","text":"ما معنى الكلمة هاي؟"},
    {"intent":"unknown","text":"اضبط المنبه على الساعة السابعة."},
    {"intent":"unknown","text":"قم بتشغيل البلوتوث"},
    {"intent":"unknown","text":"خذنى إلى المنزل"},
    {"intent":"unknown","text":"أين أقرب صيدلية؟"},
    {"intent":"unknown","text":"شغّل جهاز الإنذار"},
    {"intent":"unknown","text":"ابحث عن المطاعم القريبة"},
    {"intent":"unknown","text":"افتح الرسائل"},
    {"intent":"unknown","text":"ما هي أسعار الذهب اليوم؟"},
    {"intent":"unknown","text":"افتح البريد الإلكتروني"},
    {"intent":"unknown","text":"أظهر الوقت الآن"}
]
# Create the DataFrame
df = pd.DataFrame(data)

# Preview
print(df.head())
print(df['intent'].value_counts())
# Out:
#      intent                            text
# 0  pay_bill  ادفع فاتورة الكهرباء الخاصة بك
# 1  pay_bill    ادفع فاتورة المياه الخاصة بك
# 2  pay_bill  ادفع فاتورة الإنترنت الخاصة بك
# 3  pay_bill               ادفع فاتورة هاتفك
# 4  pay_bill     ادفع فاتورة الغاز الخاصة بك
# intent
# unknown          31
# pay_bill         30
# p2p_transfer     30
# check_balance    30
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.to_csv("manual_auglmentation_ar2en2ar.csv", index=False)
